# %%
import pymysql
database = pymysql.connect(host='localhost',database="nigcock",user='root',password='121212')

cr=database.cursor()

cr.execute("show tables")
cr.fetchall()
for nig in cr:
    print(nig)

cr.execute("create table test(d_id int,fld int)")
database.commit()
a=int(input("enter the d_id "))
b=int(input("enter the field "))
cr.execute("insert into test values(%d,%d)",a,b)
database.commit()
cr.close()
database.close()
# Out:
# database made successfully
